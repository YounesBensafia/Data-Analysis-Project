# %%
import pandas as pd

face_landmarks = pd.read_csv('face_landmarks.csv')

face_landmarks.head()
# Out:
#            filename  landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  \
# 0  001_fe3347c0.jpg      0.419798      0.573023     -0.039810      0.420517
# 1  002_8f8da10e.jpg      0.520826      0.697175     -0.050595      0.522756
# 2  003_57612506.jpg      0.621778      0.484095     -0.060141      0.645360
# 3  004_f61e7d0c.jpg      0.561612      0.387074     -0.022413      0.576896
# 4  005_582c121a.jpg      0.483484      0.423625     -0.020486      0.478826
#
#    landmark_1_y  landmark_1_z  landmark_2_x  landmark_2_y  landmark_2_z  ...  \
# 0      0.525765     -0.107200      0.422135      0.539216     -0.048565  ...
# 1      0.632175     -0.140970      0.521144      0.649325     -0.064100  ...
# 2      0.440028     -0.100363      0.634517      0.459109     -0.056341  ...
# 3      0.363394     -0.064286      0.569311      0.368939     -0.029127  ...
# 4      0.393252     -0.071255      0.482558      0.400763     -0.030569  ...
#
# ...

# %%
face_landmarks.describe()
# Out:
#        landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  landmark_1_y  \
# count   1596.000000   1596.000000   1596.000000   1596.000000   1596.000000
# mean       0.502696      0.475271     -0.036054      0.503309      0.431340
# std        0.082174      0.129399      0.015286      0.093664      0.117061
# min        0.165948      0.170788     -0.109775      0.129583      0.141571
# 25%        0.460007      0.379893     -0.045309      0.452547      0.347341
# 50%        0.501152      0.478082     -0.034510      0.501667      0.432762
# 75%        0.543758      0.568109     -0.025176      0.554046      0.514110
# max        0.932596      0.819780     -0.003050      0.950980      0.746895
#
#        landmark_1_z  landmark_2_x  landmark_2_y  landmark_2_z  landmark_3_x  \
# count   1596.000000   1596.000000   1596.000000   1596.000000   1596.000000
# mean      -0.081240      0.502814      0.443277     -0.040699      0.489844
# ...

# %%
import seaborn as sns

missing_data = face_landmarks.isnull().any().any()
print(f"Missing data in the dataset: {missing_data}")
# Out:
# Missing data in the dataset: False

# %%
face_landmarks.head(100)
# Out:
#             filename  landmark_0_x  landmark_0_y  landmark_0_z  landmark_1_x  \
# 0   001_fe3347c0.jpg      0.419798      0.573023     -0.039810      0.420517
# 1   002_8f8da10e.jpg      0.520826      0.697175     -0.050595      0.522756
# 2   003_57612506.jpg      0.621778      0.484095     -0.060141      0.645360
# 3   004_f61e7d0c.jpg      0.561612      0.387074     -0.022413      0.576896
# 4   005_582c121a.jpg      0.483484      0.423625     -0.020486      0.478826
# ..               ...           ...           ...           ...           ...
# 95  096_75710434.jpg      0.466961      0.610337     -0.034903      0.487104
# 96  097_9a6bf61f.jpg      0.622696      0.716845     -0.050223      0.648399
# 97  098_dd1405fc.jpg      0.532325      0.498751     -0.023230      0.549618
# 98  099_c22d3e48.jpg      0.523551      0.221612     -0.024820      0.532322
# 99  100_31ff9373.jpg      0.603076      0.411048     -0.017962      0.600539
#
# ...
